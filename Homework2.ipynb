# %% [markdown]
# ### Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diện tích và chu vi của nó.

# %%
a = float(input())
b = float(input())
print(a*b)
print((a+b)/2)

# %% [markdown]
# ### Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
a = float(input())
print((a**2)*3.14)
print(a*2*3.14)

# %% [markdown]
# ### Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểm tra xem nó có thể là độ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra màn hình.

# %%
a = float(input())
b = float(input())
c = float(input())
if a+b>c and a+c>b and b+c>a:
      if a == b == c:
            print("Đây là tam giác đều")
      elif a==b or a==c or b==c:
            print("Đây là tam giác cân")
      elif a**2+b**2==c**2 or a**2+c**2==b**2 or b**2+c**2==b**2:
            print("Đây là tam giác vuông")
      else:
            print("Đây là tam giác thường")
      p = a+b+c
      d = (p/2*(p/2-a)*(p/2-b)*(p/2-c))**0.5     
      print(f"Chu vi là {p}")
      print(f"Diện tích là {d}")
else:
      print("Khong la ba canh cua mot tam giac")

# %% [markdown]
# ### Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a = float(input())
b = float(input())
print(-b/a)

# %% [markdown]
# ### Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
a,b,c = map(float,input().split())
d = b**2 - 4*a*c
if d<0:
    print("vô nghiệm ")
elif d == 0:
    print(-b/(2*a))
else:
    print((-b+d**0.5)/(2*a))
    print((-b-d**0.5)/(2*a))

# %% [markdown]
# ### Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bàn phím).

# %%
a,b,c,d = map(float,input("Nhập 4 số bất kì").split())
e = max(a,b,c,d)
print(f"Số lớn nhất là {e}")

# %% [markdown]
# ### Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bàn phím).

# %%
a,b,c,d = map(float,input("Nhập 4 số bất kì").split())
e = min(a,b,c,d)
print(f"Số nhỏ nhất là {e}")

# %% [markdown]
# ### Bài 8: Giải hệ phương trình tuyến tính:
# ### ax + by = m
# ### cx + dy = n

# %%
a,b,c,d,m,n = map(float,input("Nhập các giá trị a,b,c,d,m,n ").split())
x = ((n*b)-(d*m))/((c*b)-(d*a))
y = (m-a*x)/b
print(f"Giá trị của x là {x}")
print(f"Giá trị của y là {y}")

# %% [markdown]
# ### Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây.

# %%
x = float(input("Số giây thực hiện công việc là "))
a = x//3600
b = (x-a*3600)//60
c = x - a*3600 - b*60
print(f"Thời gian thực hiện công việc là {a} giờ {b} phút {c} giây")

# %% [markdown]
# ### Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vào một điểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
a,b = map(float,input("Toạ độ tâm đường tròn ").split())
r = float(input("Bán kính đường tròn là "))
x,y = map(float,input("Toạ độ điểm A bất kì ").split())
if (x-a)**2 + (y-b)**2 == r**2:
    print("Điểm A thuộc đường tròn")
else:
    print("Điểm A không thuộc đường tròn")

# %% [markdown]
# ### Bài 11: Tính x^y (Với x, y là số thực)

# %%
x,y = map(float,input("Nhập 2 số thực x và y ").split())
print(x**y)
