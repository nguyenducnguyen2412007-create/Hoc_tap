# %% [markdown]
# ### W7A1 Viết hàm tìm kiếm nhị phân trên một danh sách đã được sắp xếp tăng dần. Trả về chỉ số của phần tử hoặc -1 nếu không tìm thấy. mẫu hàm: def binary_search(arr, left, right, target):

# %%
def binary_search(arr, left, right, target):
    while left <= right:
        mid = left + (right - left) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1
mang_da_sap_xep = [int(x) for x in input("Nhập mảng đã sắp xếp (các phần tử cách nhau bằng dấu cách): ").split()]
so_can_tim = int(input("Nhập số cần tìm: "))
ket_qua = binary_search(mang_da_sap_xep, 0, len(mang_da_sap_xep) - 1, so_can_tim)
if ket_qua != -1:
    print(f"Phần tử được tìm thấy tại chỉ số: {ket_qua}")
else:
    print("Không tìm thấy phần tử trong mảng.")

# %% [markdown]
# ### W7A2Cho danh sách arr và một số nguyên x, đếm xem x xuất hiện bao nhiêu lần trong danh sách. def count_occurrences(arr, x) > int:

# %%
def count_occurrences(arr, x) -> int:
    return arr.count(x)
danh_sach = [int(x) for x in input("Nhập một danh sách các số, cách nhau bằng dấu phẩy: ").split(",")]
so_can_tim = int(input("Nhập số bạn muốn đếm: "))
print(f"Số {so_can_tim} xuất hiện {count_occurrences(danh_sach, so_can_tim)} lần.")

# %% [markdown]
# ### W7A3 Viết hàm thực hiện thuật toán bubble sort, Selection Sort để sắp xếp danh sách theo thứ tự tăng dần. Sắp xếp nổi bọt (Bubble Sort); Sắp xếp chọn (Selection Sort)

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        swapped = False
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                swapped = True
        if not swapped:
            break
    return arr
danh_sach_1 = [int(x) for x in input("Nhập danh sách số nguyên, cách nhau bằng dấu phẩy: ").split(",")]
print("Bubble Sort:", bubble_sort(danh_sach_1))

# %% [markdown]
# ### W7A4 Viết hàm tìm phần tử có số lần xuất hiện nhiều nhất trong danh sách. Nếu có nhiều phần tử cùng số lần, trả về phần tử xuất hiện trước.

# %%
def tim_phan_tu_pho_bien_nhat(arr):
    if not arr:
        return None
    dem_so_lan = {}
    for num in arr:
        if num in dem_so_lan:
            dem_so_lan[num] += 1
        else:
            dem_so_lan[num] = 1
    phan_tu_max = None
    so_lan_max = 0
    for num, count in dem_so_lan.items():
        if count > so_lan_max:
            so_lan_max = count
            phan_tu_max = num
    return phan_tu_max
danh_sach_1 = [int(x) for x in input("Nhập danh sách phần tử (cách nhau bằng dấu phẩy): ").split(",")]
print("Phần tử xuất hiện nhiều nhất:", tim_phan_tu_pho_bien_nhat(danh_sach_1))

# %% [markdown]
# ### W7A5 Cho danh sách các số nguyên và một số X, đếm tất cả các cặp (a, b) sao cho a + b = X. c

# %%
def count_pairs_sum_optimal(arr, X):
    dem = 0
    da_thay = {}  
    for num in arr:
        phan_bu = X - num
        if phan_bu in da_thay:
            dem += da_thay[phan_bu]
        if num in da_thay:
            da_thay[num] += 1
        else:
            da_thay[num] = 1
    return dem
danh_sach = [int(x) for x in input("Nhập danh sách số nguyên (cách nhau bằng dấu cách): ").split()]
tong_X = int(input("Nhập giá trị X: "))
print("Cách tối ưu - Số cặp thỏa mãn:", count_pairs_sum_optimal(danh_sach, tong_X))

# %% [markdown]
# ### W7A6 Bạn được cung cấp một danh sách các danh sách lồng nhau, vd [[1, 2, 3], [4, 5], [6, 7, 8, 9]], hãy làm phẳng danh sách

# %%
chuoi_co_san = input("Nhập chuỗi có sẵn: ").split(",")
chuoi_phang = []
for sublist in chuoi_co_san:
    for item in sublist:
        chuoi_phang.append(item)
print(chuoi_phang)

# %% [markdown]
# ### W7A7 Cho một danh sách các số nguyên nums, hãy tìm độ dài của dãy con tăng nghiêm ngặt dài nhất (không nhất thiết phải liền kề).

# %%
def length_of_lis_dp(nums):
    if not nums:
        return 0
    dp = [1] * len(nums)
    for i in range(1, len(nums)):
        for j in range(i):
            if nums[i] > nums[j]:
                dp[i] = max(dp[i], dp[j] + 1)
    return max(dp)
danh_sach = [int(x) for x in input("Nhập dãy số (cách nhau bằng dấu cách): ").split()]
print(f"Độ dài dãy con tăng dài nhất: {length_of_lis_dp(danh_sach)}")

# %% [markdown]
# ### W7A8 Bạn được cung cấp: một danh sách các khoảng thời gian interval = [[l1, r1], [l2, r2], ...] và một danh sách các truy vấn queries = [q1, q2, ...]  Với mỗi truy vấn q, hãy tìm độ dài nhỏ nhất của khoảng thời gian [li, ri] sao cho li ≤ q ≤ ri.  Nếu không tồn tại khoảng thời gian nào như vậy, hãy trả về -1 cho truy vấn đó. solve in < O(m.n), hint: binary search in the queries list
